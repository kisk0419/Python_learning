# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-83845d2a-7d94-4355-9a45-9a3555d17d3b" name="files[]" multiple disabled />
#      <output id="result-83845d2a-7d94-4355-9a45-9a3555d17d3b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Lec_28_test.xlsx to Lec_28_test.xlsx

# %%
uploaded
# Out:
# {'Lec_28_test.xlsx': b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\x00|l\x98\x16l\x01\x00\x00\xa0\x05\x00\x00\x13\x00\x08\x02[Content_Types].xml \xa2\x04\x02(
# ...

# %%
dframe = pd.read_excel('Lec_28_test.xlsx', sheet_name='Sheet1') # ExcelファイルからDataFrameを作成する

# %%
dframe
# Out:
#    This is a test  Unnamed: 1  Unnamed: 2
# 0              23        6678         456
# 1             234         678         456
# 2             234           7         345
# 3              34          56         234
# 4               5         456        4365
